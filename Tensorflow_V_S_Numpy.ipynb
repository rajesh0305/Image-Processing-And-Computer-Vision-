# %% [markdown]
# <a href="https://colab.research.google.com/github/rajesh0305/Image-Processing-And-Computer-Vision-/blob/main/Tensorflow_V_S_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import time

#Define Matrix dimensions
n = 10000 # A Larger size for a more noticable performence difference

#generate two random matrices using Numpy
A = np.random.rand(n,n)
B = np.random.rand(n,n)

#convert the numpy metrices to tensorflow tensors with the same values
A_tf = tf.constant(A, dtype = tf.float32)
B_tf  = tf.constant(B, dtype = tf.float32)

#Numpy matrix multiplication (on CPU)
start_time  = time.time()
c_np = np.matmul(A,B)
end_time  = time.time()
numpy_time  = end_time - start_time
print(f"Numpy matrix multiplication time: {numpy_time:6f}seconds")

#Tensorflow matrix Multiplication (on GPU ,if available)
start_time  = time.time()
with tf.device("/GPU:0"):
  c_tf = tf.matmul(A_tf,B_tf)
end_time = time.time()
tensorflow_time = end_time-start_time
print(f"Tensorflow matrix multiplication time on GPU: {tensorflow_time:6f}seconds")
# Out:
# Numpy matrix multiplication time: 35.814407seconds
# Tensorflow matrix multiplication time on GPU: 0.128820seconds
