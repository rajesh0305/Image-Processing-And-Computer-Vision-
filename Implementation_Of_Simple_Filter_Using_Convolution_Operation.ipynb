# %% [markdown]
# <a href="https://colab.research.google.com/github/rajesh0305/Image-Processing-And-Computer-Vision-/blob/main/Implementation_Of_Simple_Filter_Using_Convolution_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve2d
from skimage import data ,color

# %%
#load grayscale images
image = color.rgb2gray(data.coffee())

# %%
#Define a simple edge detection filter
filter = np.array([[-1, -1, -1],
                  [0, 0, 0],
                  [1, 1, 1]])

# %%
#Apply Convolution Operation
convolved = convolve2d(image, filter, mode='same', boundary='symm')

# %%
#show result
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Original Image')
plt.imshow(image,cmap='gray')
plt.subplot(1,2,2)
plt.title('After Convolution Operation')
plt.imshow(convolved,cmap='gray')
plt.show()
